# %% [markdown]
# # PROGRAM EXERCISE 14 - DRAW THIS PATTERN

# %%
# PROGRAM 4-19 TAKEN FROM THE BOOK THAT I HAVE ALREADY DONE
# NOW I NEED TO SHOW IT THE OPPOSITE WAY.

# THIS PROGRAM DISPLAYS A TRIANGLE PATTERN.
BASE_SIZE = 8
for r in range(BASE_SIZE):
    for c in range(r + 1):
        print('*', end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********

# %%
# Asked ChatGPT for some help making this show the opposite way 
# and it looks like I need to change the value for r in range (BASE_SIZE, 0, -1):
# and for c in range(r):

# %%
BASE_SIZE = 8
for r in range(BASE_SIZE, 0, -1):
    for c in range(r):
        print('*', end='')
    print()
# Out:
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
BASE_SIZE = 20
for r in range(BASE_SIZE, 0, -1):
    for c in range(r):
        print('*', end='')
    print()
# Out:
# ********************
# *******************
# ******************
# *****************
# ****************
# ***************
# **************
# *************
# ************
# ***********
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
BASE_SIZE = 100
for r in range(BASE_SIZE, 0, -1):
    for c in range(r):
        print('*', end='')
    print()
# Out:
# ****************************************************************************************************
# ***************************************************************************************************
# **************************************************************************************************
# *************************************************************************************************
# ************************************************************************************************
# ***********************************************************************************************
# **********************************************************************************************
# *********************************************************************************************
# ********************************************************************************************
# *******************************************************************************************
# ...
